# %%
import pandas as pd
from matplotlib import pyplot as plt

header = pd.read_csv('/Users/Project/Desktop/gdelt/gdeltdata/CSV.header.fieldids.csv')
header_list=list()
for c in header:
    header_list.append(c)
df = pd.read_csv('/Users/Project/Desktop/gdelt/gdeltdata/gdelt.csv',names=header_list)

# %%
df.head(5)
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0      760359406  20180530     201805  2018     2018.4110        USA
# 1      794860320  20181016     201810  2018     2018.7836        USA
# 2      771702393  20180713     201807  2018     2018.5288        USA
# 3      741727342  20180325     201803  2018     2018.2329        USA
# 4      741652542  20180324     201803  2018     2018.2301        CHN
#
#       Actor1Name Actor1CountryCode  Actor1KnownGroupCode  Actor1EthnicCode  \
# 0  UNITED STATES               USA                   NaN               NaN
# 1         THE US               USA                   NaN               NaN
# 2         THE US               USA                   NaN               NaN
# 3     WASHINGTON               USA                   NaN               NaN
# 4          CHINA               CHN                   NaN               NaN
#
#                          ...                          Actor2Geo_FeatureID  \
# 0                        ...                                           CH
# 1                        ...                                           US
# 2                        ...                                       531871
# 3                        ...                                           WA
# 4                        ...                                       531871
#
#    ActionGeo_Type                                ActionGeo_FullName  \
# 0               3  White House, District of Columbia, United States
# 1               1                                             China
# 2               3   Washington, District of Columbia, United States
# 3               2                         Washington, United States
# 4               3   Washington, District of Columbia, United States
#
#    ActionGeo_CountryCode  ActionGeo_ADM1Code ActionGeo_Lat ActionGeo_Long  \
# 0                     US                USDC       38.8951       -77.0364
# 1                     CH                  CH       35.0000       105.0000
# 2                     US                USDC       38.8951       -77.0364
# 3                     US                USWA       47.3917      -121.5710
# 4                     US                USDC       38.8951       -77.0364
#
#   ActionGeo_FeatureID  DATEADDED  \
# 0              531871   20180530
# 1                  CH   20181016
# 2              531871   20180713
# 3                  WA   20180325
# 4              531871   20180324
#
#                                            SOURCEURL
# 0  http://180dfo.com/2018/05/china-reportedly-lin...
# 1  http://180dfo.com/2018/10/even-optimists-are-g...
# 2  http://2016carsreview.net/2018/07/united-state...
# 3  http://abc27.com/ap/chinese-warns-against-trad...
# 4  http://acupuncturecentral.net/2018/03/trump-tr...
#
# [5 rows x 58 columns]

# %%
size_us_1  = int(len(df[df.iloc[:,5]=='USA']))
size_chn_1 = len(df[df.iloc[:,5]=='CHN'])
size_us_2  = len(df[df.iloc[:,15]=='USA'])
size_chn_2  = len(df[df.iloc[:,15]=='CHN'])
y = [size_us_1,size_chn_1,size_us_2,size_chn_2]
x = [1000,2000,3000]
